# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\IMAGE PROCESSING'

# %%
# Let us import one image in our Jupyter environment and open that in the notebook itself

image1 = Image.open("snow.png")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=214x236 at 0x2DE77F84580>

# %%
image1.show()

# %%
image1.save("pic1.png")

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'apple.png',
#  'Automate IP using Python.ipynb',
#  'baloon.jfif',
#  'bfly.jpg',
#  'Bitwise.ipynb',
#  'blurred.jpg',
#  'Blurring Effect.ipynb',
#  'burred.jpg',
#  'butterfly.jfif',
#  'Canvas Image.ipynb',
#  'canvas.png',
#  'car.png',
#  'cat.png',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'crop.png',
#  'diceimg.png',
#  'diff1.jpg',
#  'diff2.jpg',
#  'Difference between Images.ipynb',
#  'dog.jfif',
#  'double heart.webp',
#  'Drawing contour lines for an image..ipynb',
#  'earth.png',
#  'emoji.jfif',
#  'face.jpg',
#  'face1.jpg',
#  'fall.jfif',
#  'fall.png',
#  'feather.jfif',
#  'filtering on an image.ipynb',
#  'flower.jfif',
#  'flower2.jpg',
#  'fruit.jpg',
#  'gfg_dummy_pic.png',
#  'GreyScale.ipynb',
#  'heart.png',
#  'horse.png',
#  'im1.jfif',
#  'im2.jpg',
#  'im3.jpg',
#  'im4.jpg',
#  'Image manipulation.ipynb',
#  'Image Restoration 1.ipynb',
#  'image1.webp',
#  'Image_from_array.png',
#  'img.png',
#  'imlogo.png',
#  'Intensive Transformation.ipynb',
#  'Interpolation.ipynb',
#  'Iverting from one folder to another.ipynb',
#  'Listing Images.ipynb',
#  'logo.png',
#  'logo4.png',
#  'logo5.png',
#  'logo6.png',
#  'mario.png',
#  'Matrix To Image.ipynb',
#  'micky.png',
#  'modi.jfif',
#  'montage.png',
#  'montege.ipynb',
#  'moon.png',
#  'nature.jpg',
#  'nature.png',
#  'new.png',
#  'Noise.ipynb',
#  'noise.png',
#  'noise1.jpg',
#  'noisy.jfif',
#  'panda.jfif',
#  'pic1.png',
#  'Quantization & Down sampling.ipynb',
#  'read, write and display.ipynb',
#  'Remove BG.ipynb',
#  'rose.jfif',
#  'sample2.ipynb',
#  'Segmentation.ipynb',
#  'snow.png',
#  'square.jpg',
#  'text removal.ipynb',
#  'text_removed_image.jpg',
#  'tottenham.jpg',
#  'watermark.png',
#  'watermark2.png',
#  'watermark3.png',
#  'watermark4.png',
#  'watermark5.png',
#  'watsapp.png']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# bfly & .jpg
# blurred & .jpg
# burred & .jpg
# diff1 & .jpg
# diff2 & .jpg
# face & .jpg
# face1 & .jpg
# flower2 & .jpg
# fruit & .jpg
# im2 & .jpg
# im3 & .jpg
# im4 & .jpg
# nature & .jpg
# noise1 & .jpg
# square & .jpg
# text_removed_image & .jpg
# tottenham & .jpg

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# bfly.jpg
# blurred.jpg
# burred.jpg
# diff1.jpg
# diff2.jpg
# face.jpg
# face1.jpg
# flower2.jpg
# fruit.jpg
# im2.jpg
# im3.jpg
# im4.jpg
# nature.jpg
# noise1.jpg
# square.jpg
# text_removed_image.jpg
# tottenham.jpg

# %%
# Creating new Directory using OS library
os.mkdir('NewExtnsn')
# Note: If you already have a directory with this name, you will get error.

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("newExtnsn/{}.pdf".format(fn))

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
# Note: If you already have a directory with this name, you will get error.

# %%
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))

# %%
image2 = Image.open("im3.jpg")
image2 = image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=321x157 at 0x2DE7814DD00>

# %%
# Creating new Directory using OS library
os.mkdir('b&w')

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.convert(mode = 'L')
        im.save("b&w/{}_bw.{}".format(fn, fext))

# %%
#rotating the image to 55 Degree angle
image3 = Image.open("im3.jpg")
image3.rotate(55).save("im2.jpg")
Image3 = Image.open("im2.jpg")

# %%
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=321x157 at 0x2DE78220790>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
