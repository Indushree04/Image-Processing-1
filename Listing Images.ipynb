# %%
#listing only png Images
#import the modules
import os
from os import listdir

#get the path/directory
folder_dir="D:/Indushree"
for images in os.listdir(folder_dir):
    
    #check if the images end with png
    if(images.endswith(".png")):
        print(images)
# Out:
# apple.png
# canvas.png
# car.png
# cat.png
# cat_damaged.png
# cat_mask.png
# crop.png
# earth.png
# heart.png
# logo.png
# logo4.png
# mario.png
# micky.png
# moon.png
# watermark.png
# watermark2.png
# watermark3.png
# watermark4.png
# watermark5.png
# watsapp.png

# %%
#Listing all the images
#import the modules
import os
from os import listdir

#get the path/directory
folder_dir="D:/Indushree"
for images in os.listdir(folder_dir):
        print(images)
# Out:
# apple.png
# baloon.jfif
# bfly.jpg
# bottle.jfif
# butterfly.jfif
# canvas.png
# car.png
# cat.png
# cat_damaged.png
# cat_mask.png
# crop.png
# dog.jfif
# earth.png
# emoji.jfif
# fall.jfif
# feather.jfif
# flower.jfif
# flower1.jfif
# flower2.jpg
# heart.png
# im1.jfif
# im2.jpg
# im3.jpg
# im4.jpg
# image_sharpen.jpg
# logo.png
# logo4.png
# mario.png
# micky.png
# modi.jfif
# moon.png
# nature.jpg
# noisy.jfif
# panda.jfif
# rose.jfif
# shapes.jpg
# square.jpg
# tottenham.jpg
# watermark.png
# watermark2.png
# watermark3.png
# watermark4.png
# watermark5.png
# watsapp.png

# %%
#Display all the images
#import necessary packages 
import cv2 
import os 
import glob 
import matplotlib.pyplot as plt 
# %matplotlib inline 
 
#Set the path where images are stored 
img_dir = "D:/Indushree" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = cv2.imread(f1) 
    data.append(img) 
    plt.figure() 
    plt.imshow(img)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_2820/56756770.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
